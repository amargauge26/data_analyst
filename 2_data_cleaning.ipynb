# %% [markdown]
# <a href="https://colab.research.google.com/github/amargauge26/data_analyst/blob/main/2_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("/content/NFL_Play_by_Play_2009-2017_(v4)[1].csv")
# Out:
# <ipython-input-34-d311a949c782>:5: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/NFL_Play_by_Play_2009-2017_(v4)[1].csv")

# %%
df.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
df.columns
# Out:
# Index(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField',
#        ...
#        'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post',
#        'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season'],
#       dtype='object', length=102)

# %%
missing_val = df.isnull().sum()
missing_val
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         32296
#              ...
# Win_Prob     12855
# WPA           2733
# airWPA      134034
# yacWPA      134158
# Season           1
# Length: 102, dtype: int64

# %%
missing_val[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            32296
# time              104
# TimeUnder           0
# TimeSecs          104
# PlayTimeDiff      208
# SideofField       263
# dtype: int64

# %%
total_cells = np.product(df.shape)

total_missing = missing_val.sum()

# %%
# we are trying get how missing value persent bloacks we have to total blocks

percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 27.643897149646623

# %%
missing_val[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            32296
# time              104
# TimeUnder           0
# TimeSecs          104
# PlayTimeDiff      208
# SideofField       263
# dtype: int64

# %%
df.shape
# Out:
# (218859, 102)

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.shape
# Out:
# (218859, 102)

# %%
col_with_na_drop = df.dropna(axis=1)

# %%
col_with_na_drop.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  HomeTeam  AwayTeam  \
# 0              1            39   0  ...       PIT       TEN
# 1              1             5   0  ...       PIT       TEN
# 2              1            -3   0  ...       PIT       TEN
# 3              1             0   0  ...       PIT       TEN
# 4              1             0   0  ...       PIT       TEN
#
#    Timeout_Indicator posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 0                  0                    3                           3
# ...

# %%
df.shape[1]
# Out:
# 102

# %%
col_with_na_drop.shape[1]
# Out:
# 36

# %%
#automate the process
subset_df = df.loc[:,"EPA":"Season"].head()

# %%
subset_df
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN  2009.0
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899  2009.0
# 2      0.489207  0.551088 -0.040295       NaN       NaN  2009.0
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239  2009.0
# 4      0.441071  0.461217  0.097712       NaN       NaN  2009.0

# %%
subset_df.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000  2009.0
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899  2009.0
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000  2009.0
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239  2009.0
# 4      0.441071  0.461217  0.097712  0.000000  0.000000  2009.0

# %%
subset_df.fillna(method="bfill",axis=0).fillna(0)
# Out:
# <ipython-input-53-aaa6ba71faa0>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_df.fillna(method="bfill",axis=0).fillna(0)
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899  2009.0
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899  2009.0
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239  2009.0
# ...
