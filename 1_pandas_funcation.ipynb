# %% [markdown]
# <a href="https://colab.research.google.com/github/amargauge26/data_analyst/blob/main/1_pandas_funcation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/data_analyst/titanic (1).csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.select_dtypes(include="int64").columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (891, 12)

# %%
df.rename(columns={"SibSp":"siblings/spouses","Parch":"parents/children"},inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'siblings/spouses', 'parents/children', 'Ticket', 'Fare', 'Cabin',
#        'Embarked'],
#       dtype='object')

# %%
df["Embarked"]=df["Embarked"].map({"C":"cherbourg","Q":"Queenstown","S":"Southhampton"})

# %%
df["Embarked"]
# Out:
# 0      Southhampton
# 1         cherbourg
# 2      Southhampton
# 3      Southhampton
# 4      Southhampton
#            ...
# 886    Southhampton
# 887    Southhampton
# 888    Southhampton
# 889       cherbourg
# 890      Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
df.query("Age >40").value_counts().sum()
# Out:
# 65

# %%
df[df["Embarked"].isin(["Cherbourg" , "Queenstown"])].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 5             6         0       3               Moran, Mr. James    male
# 16           17         0       3           Rice, Master. Eugene    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female
# 32           33         1       3       Glynn, Miss. Mary Agatha  female
#
#      Age  siblings/spouses  parents/children  Ticket     Fare Cabin  \
# 5    NaN                 0                 0  330877   8.4583   NaN
# 16   2.0                 4                 1  382652  29.1250   NaN
# 22  15.0                 0                 0  330923   8.0292   NaN
# 28   NaN                 0                 0  330959   7.8792   NaN
# 32   NaN                 0                 0  335677   7.7500   NaN
#
#       Embarked
# 5   Queenstown
# 16  Queenstown
# 22  Queenstown
# 28  Queenstown
# 32  Queenstown

# %%
df.drop(columns=["PassengerId","Cabin","Name"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'siblings/spouses',
#        'parents/children', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
# Out:
# <ipython-input-54-993656b341a6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)

# %%
df["Embarked"].fillna(df["Embarked"].mode, inplace=True)

# %%
df.groupby('Sex')["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Sex')["Survived"].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
sns.barplot(x="Sex" , y="Survived" , data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
df.sort_values(by="Fare",ascending=False)
# Out:
#      Survived  Pclass     Sex        Age  siblings/spouses  parents/children  \
# 258         1       1  female  35.000000                 0                 0
# 737         1       1    male  35.000000                 0                 0
# 679         1       1    male  36.000000                 0                 1
# 88          1       1  female  23.000000                 3                 2
# 27          0       1    male  19.000000                 3                 2
# ..        ...     ...     ...        ...               ...               ...
# 633         0       1    male  29.699118                 0                 0
# 413         0       2    male  29.699118                 0                 0
# 822         0       1    male  38.000000                 0                 0
# 732         0       2    male  29.699118                 0                 0
# 674         0       2    male  29.699118                 0                 0
#
#        Ticket      Fare      Embarked
# ...

# %%
df1=df.loc[(df["Age"]>=20) & (df["Age"]<=30)]

# %%
df1['Age'].max()
# Out:
# 30.0

# %%
df1.groupby("Embarked")["Survived"].sum()
# Out:
# Embarked
# Queenstown      25
# Southhampton    74
# cherbourg       40
# Name: Survived, dtype: int64

# %%
df.loc[ (df['siblings/spouses'])==(df['parents/children']) , ['siblings/spouses', 'parents/children', 'Age', 'Survived']]
# Out:
#      siblings/spouses  parents/children        Age  Survived
# 2                   0                 0  26.000000         1
# 4                   0                 0  35.000000         0
# 5                   0                 0  29.699118         0
# 6                   0                 0  54.000000         0
# 10                  1                 1   4.000000         1
# ..                ...               ...        ...       ...
# 884                 0                 0  25.000000         0
# 886                 0                 0  27.000000         0
# 887                 0                 0  19.000000         1
# 889                 0                 0  26.000000         1
# 890                 0                 0  32.000000         0
#
# [598 rows x 4 columns]

# %%
df.iloc[1:10,1:4]
# Out:
#    Pclass     Sex        Age
# 1       1  female  38.000000
# 2       3  female  26.000000
# 3       1  female  35.000000
# 4       3    male  35.000000
# 5       3    male  29.699118
# 6       1    male  54.000000
# 7       3    male   2.000000
# 8       3  female  27.000000
# 9       2  female  14.000000

# %%
import numpy as np

df["age_group"]= pd.cut(df['Age'],bins=[0,12,18,30,50,80],labels=["0-12","12-18","18-30","30-50", "50-100"])

# %%
df["age_group"].value_counts()
# Out:
# age_group
# 18-30     447
# 30-50     241
# 12-18      70
# 0-12       69
# 50-100     64
# Name: count, dtype: int64

# %%
df["fmaily_size"]=df.apply(lambda r :1+r['parents/children'] + r['siblings/spouses'] , axis=1)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  siblings/spouses  parents/children  \
# 0           0       3    male  22.000000                 1                 0
# 1           1       1  female  38.000000                 1                 0
# 2           1       3  female  26.000000                 0                 0
# 3           1       1  female  35.000000                 1                 0
# 4           0       3    male  35.000000                 0                 0
# ..        ...     ...     ...        ...               ...               ...
# 886         0       2    male  27.000000                 0                 0
# 887         1       1  female  19.000000                 0                 0
# 888         0       3  female  29.699118                 1                 2
# 889         1       1    male  26.000000                 0                 0
# 890         0       3    male  32.000000                 0                 0
#
# ...

# %%
index_with_max_fare = df["Fare"].idxmax()

# %%
index_with_max_fare
# Out:
# 258

# %%
dummy_sex = pd.get_dummies(df['Sex'])

# %%
dummy_sex
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 886   False   True
# 887    True  False
# 888    True  False
# 889   False   True
# 890   False   True
#
# [891 rows x 2 columns]

# %%
dummy_embarked = pd.get_dummies(df['Embarked'], prefix='Embarked')

# %%
titanic_df = pd.concat([df, dummy_sex, dummy_embarked], axis=1)

# %%
titanic_df.to_numpy()
# Out:
# array([[0, 3, 'male', ..., False, True, False],
#        [1, 1, 'female', ..., False, False, True],
#        [1, 3, 'female', ..., False, True, False],
#        ...,
#        [0, 3, 'female', ..., False, True, False],
#        [1, 1, 'male', ..., False, False, True],
#        [0, 3, 'male', ..., True, False, False]], dtype=object)

# %%
titanic_df
# Out:
#      Survived  Pclass     Sex        Age  siblings/spouses  parents/children  \
# 0           0       3    male  22.000000                 1                 0
# 1           1       1  female  38.000000                 1                 0
# 2           1       3  female  26.000000                 0                 0
# 3           1       1  female  35.000000                 1                 0
# 4           0       3    male  35.000000                 0                 0
# ..        ...     ...     ...        ...               ...               ...
# 886         0       2    male  27.000000                 0                 0
# 887         1       1  female  19.000000                 0                 0
# 888         0       3  female  29.699118                 1                 2
# 889         1       1    male  26.000000                 0                 0
# 890         0       3    male  32.000000                 0                 0
#
# ...

# %%
titanic_df.to_excel('output.xlsx', index=False)
